# %% [markdown]
# 4) Relatório Educação e Saúde: Informar nome, data de nascimento, id e data que tiveram dengue dos cidadãos de XPTO que frequentaram a escola e tiveram dengue.

# %% [markdown]
# # Import das bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Codigo de Tratamento de Dados

# %%
#Import do Arquivo da base de dados de Dengue
path_dengue = '/content/drive/MyDrive/Unifor-Ciencia de Dados/Bases de Dados/Base de Dengue3.csv'

# %%
#Import do Arquivo da base de dados de Alunos
path_alunos = '/content/drive/MyDrive/Unifor-Ciencia de Dados/Bases de Dados/Base de Alunos3.csv'

# %%
#Lendo o arquivo "path_dengue"
df_dengue = pd.read_csv(path_dengue, sep=';')

# %%
#Lendo o arquivo "path_alunos"
df_alunos = pd.read_csv(path_alunos, sep=';')

# %%
#'len' = tamanho de linhas do dataframe alunos
len(df_alunos)

# %%
#'len' tamanho de linhas do dataframe dengue
len(df_dengue)

# %%
df_alunos

# %%
df_dengue

# %%
#listagem da coluna 'Nomes' do datafame de dengue
lista_nomes_alunos = list(df_alunos['Nome'])

# %%
#criando um dataframe de alunos com dengue, chamando apenas os nomes dos alunos que tiveram dengue
df_alunos_com_dengue = df_dengue[df_dengue['Nome'].isin(lista_nomes_alunos)]

# %%
df_alunos_com_dengue
# Out:
#       ID                           Nome                  Nome da Mae  \
# 1      1            MARIA FATIMA MACIEL                   GILVAM R M
# 6      6         ANTONIO UMBELINO LAVES          JACQUES SILVA LAVES
# 18    18          FRANCISCO LAURA BRAGA         RADMJNDO COSTA BRAGA
# 22    22                          MARIA                     JOSE M T
# 30    30          KEILIANE SANTOS SOUSA                         JOSE
# 51    51                            ANA       FRANCISCO PASTOR SILVA
# 58    58           JORGE CASTRO MIRANDA        VILSON JAQUES MIRANDA
# 61    61                      FRANCISCO                   ELISEU S S
# 62    62             SHERLY SOUSA HELIO           JAGRO SANTOS HELIO
# 79    79          JEFFERSON LOPES SOUZA          JOSE OLIVEIRA SOUZA
# 96    96     EMANUELLE NAZARET CARVALHO                     JOSE F C
# 97    97          CLEIDE MIRIAN CORREIA        MICUGLE SJLVA CBRBEIA
# 99    99                          MARIA           DARIO PINTO RAFAEL
# 103  103             MURILO ROCHA SILVA                  LUCIANO A S
# 105  105        MARLEIDE DANIEL BATISTA                      ANTONIS
# 117  117  EXPEDITO APARECIDA NASCIMENTO                         JOSE
# 121  121                           JOSE                       CICERO
# 125  125        MARIA ROSILENE PINHEIRO                         JOAO
# 129  129            JULIANA COSTA SILVA       ANTONIC OLIVKERA SATVA
# 130  130     JACQUELINE SOLANGE ALMEIDA                  ANTONIO S A
# 136  136          ANTONIO ILMA CARVALHO                  ANTONIO S C
# 141  141                          MARIA            JOSE PINTO SANTOS
# 154  154                          MARIA                  JOAQUIM P R
# 155  155          MARIA LOURDES FEITOZA        MARCUS MENDES FEITOZA
# 156  156   ELIZABETE RODRIGUES FERREIRA        MANOEL SILVA FERREIRA
# 161  161                      MARIA F C                         JOSE
# 171  171         MIKAELLE SILVA HORACIO      FRANCISCO SOUZA HORACIO
# 179  179                         CARLOS       FRLACBSRO SILVA SANTOS
# 183  183             ANA CORREIA ARAUJO           PEDRO VITAL ARAUJO
# 185  185             PABLO DANTAS TELES         ELIEZER BORGES TELES
# 195  195                          MARIA  VHLVEMARBERREIRA APOLINDRIO
# 200  200                          MARIA      MILTON OLIVEIRA BARBOSA
# 207  207                          MARIA         COSME MACIEL ALMEIDA
# 218  218             ISMAEL RAQUEL JOSE                         JOSE
# 220  220                            ANA                FRENCISCO F S
# 226  226         FRANCISCO CASTRO PINTO            JOSE SEVERO PINTO
#
#                     Nome do Pai Sexo Data de Nascimento Data da Dengue
# 1                         MARIA    F          53/1/1997     20/05/2002
# 6                      QUITERIA    M         81/71/2004     14/07/2010
# 18        FRANCISCA LAURA CUNHA    M         26/11/2902     38/11/6188
# 22      FRANCISCC TAVARES RAMOS    F          75/3/1913     14/04/2816
# 30            MARIA SANTOS MOTA    F         21/03/2259      60/4/7711
# 51        CREUZA CARREIRO ALVES    F         09/03/2009      2/18/1018
# 58       FRANCCLEFYCNSTROSOARRS    M          93/5/2003     05/09/2083
# 61                     EXPEDITA    M         21/02/1985      4/14/2906
# 62      ANTONIA SOUSA MARCELINO    F         19/02/1998     01/03/2073
# 79       SOLANIE LOIES MEDEIROS    M          25/1/1774     15/05/2711
# 96      FRANCISCA NAZARET MARIA    F         24/03/2003     20/01/2017
# 97    RAIMUNDA MIRIAN VALDIRENE    F         10/01/1995     24/13/5215
# 99        MARIA VANIA RODRIGUES    F          2/10/1059     09/01/1977
# 103                   JOANA R S    M         21/12/2000     09/10/2013
# 105       MARNILCE DANIEL SILVA    F         12/03/2266     30/08/2016
# 117     GERALDA APARECIDA GOMES    M          14/4/1356     03/08/2012
# 121           NADIA SILVA SILVA    M         17/06/1974     03/10/2002
# 125                   NEIVA R C    F         08/02/6997     09/01/5904
# 129      FRANCISCA COSTA SANTOS    F         03/04/2013     29/09/2077
# 130                       MARIA    F          20/3/0896     30/09/2000
# 136           MARIA ILMA SANTOS    M         01/06/2009      7/56/2017
# 141  DARLENE OLIVEIRA SEVERIANO    F         27/04/1938      12/0/1982
# 154                       MARIA    F         29/04/1987     13/03/2030
# 155   CRISTIANE LOURDES PEREIRA    F         01/03/6051     05/01/2016
# 156      MARIA RODRIGUES AGUIAR    F         01/03/2010     15/07/9009
# 161         MARIA FERREIRA JOSE    F          94/5/2000     31/01/2012
# 171                       MARIA    F         18/01/2004     18/03/2713
# 179       FRANCISCA ALVES SOUZA    M          45/1/6946     01/11/1991
# 183                       MAAIS    F         13/03/2002     14/92/8010
# 185    FRANCISCL DANTAS MENESYR    M         04/07/2040     05/11/2018
# 195      MARIA CARNEIRO BARBOSA    F         08/05/1946     30/07/1945
# 200        MARIA SILVA OLIVEIRA    F         04/01/6947     10/11/1959
# 207  MILENA GALDENCIO RODRIGUES    F           8/9/1150     18/06/7963
# 218         ANA RAQUEL CORDEIRO    M         08/09/2010     19/02/2061
# 220      ADAILZA SANTOS BARBOSA    F          82/2/8803     20/06/2055
# 226            NEIDE CASTRO PAZ    M           5/9/1829     29/08/2008

# %%
#Informação do dataframe de alunos com dengue = como os dados são e quantas linhas nao nulas eles tem
df_alunos_com_dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 1 to 226
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  36 non-null     int64
#  1   Nome                36 non-null     object
#  2   Nome da Mae         36 non-null     object
#  3   Nome do Pai         36 non-null     object
#  4   Sexo                36 non-null     object
#  5   Data de Nascimento  36 non-null     object
#  6   Data da Dengue      36 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.2+ KB

# %%
# #Export do novo dataframe tratado (alunos com dengue)
# df_alunos_com_dengue.to_excel('Alunos com Dengue3.xlsx')

# %% [markdown]
# # Grafico de Venn

# %%
#listagem da coluna 'Nomes' do datafame de alunos
lista_nomes_alunos = list(df_alunos['Nome'])

# %%
#listagem da coluna 'Nomes' do datafame de dengue
lista_nomes_dengue = list(df_dengue['Nome'])

# %%
#Importando uma biblioteca grafica (Matplotlib)
from matplotlib import pyplot as plt
from matplotlib_venn import venn2, venn3

# %%
#Montando a funcão do diagrama de Venn
def func_venn(venn, lst, labels):

  return venn(lst, set_labels = labels)

# %%
func_venn(venn2, [set(lista_nomes_alunos), set(lista_nomes_dengue)],
          ("Lista de Nomes dos Alunos", "Lista de Nomes com Dengue"))
plt.title("Diagrama de Venn dos Alunos com Dengue")
plt.show()
